# %%
from ultralytics import YOLO
import os

# %%
model = YOLO('final2.pt')

# %%
all_data = os.listdir('/Users/shrivassudharsan/Desktop/datasets/data/test/test/images')
list_data = []
for i in range(len(all_data)):
        list_data.append(all_data[i])

# %%
print(list_data)
for i in range(len(list_data)):
    model.predict(source = list_data[i], imgsz= 640, conf = 0.6, save = True)
# Out:
# ['img-64-_jpg.rf.2ba48c34736ef14ceba1d70eeb58453f.jpg', '2022_jpg.rf.c5d5aff510c702b8605e8a812be4fd0a.jpg', 'image_98_jpg.rf.d869e28c16db4e8cf474ef917282f24f.jpg', 'pic-36-_jpg.rf.fd723bef44df2f61c6c9f213a6bfc8fc.jpg', 'pic-152-_jpg.rf.ec0e81ad3245e88ffdb9435e15e5184f.jpg', 'pic-119-_jpg.rf.2fcddb23fa46992747a5f74d9ab1db47.jpg', 'img-142-_jpg.rf.a33b5019121b6feb5833556e1d338a94.jpg', 'pic-56-_jpg.rf.667331a0c0e77acdcabfa7e0f9479ef8.jpg', 'pic-169-_jpg.rf.4e5a2a28ef5969113f9f76afd95b9ef8.jpg', 'c08c240cded9c858_jpg.rf.99ff9c39535e897f4c286fa95ab0f76f.jpg', 'pic-95-_jpg.rf.e2b9eb65063480e29d0f800b92959a6f.jpg', 'pic-170-_jpg.rf.31a96653ba906c11feb9ba8359b93e57.jpg', 'pic-77-_jpg.rf.2db9e074f17ab646082edacb560bb88d.jpg', 'image_68_jpg.rf.b6a75686618884f28d66d38b325d04ae.jpg', 'pic-59-_jpg.rf.6b5da3d60a34ba6d4e2a9a2cf65cfdbb.jpg', 'fire-16_png.rf.55408f8ce2b85d13ebcdc97ad1656038.jpg', 'img-143-_jpg.rf.d16c4767bd5d3eb54a1823c688e20cb8.jpg', '1403_jpg.rf.33d2d83173c619ad8ac57e2c839c6ae1.jp
# ...
